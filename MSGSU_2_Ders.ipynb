# %%
#If - elif - else

x = 5

if(x>6):
  print("X 4'ten büyüktür")

########

#eğer bir koşul veriyorsak ve o koşulu sağlamıyorsa else bloguna girer sağlıyorsa girmez

if(x<3):
  print("X 3 ten küçüktür")
else:
  print("x sayısı 3 tür")

######

#elif(else if) birden fazla koşullu ifadeler içindir
#eğer kendinden önce if değeri sağlanırsa içine girilmez

i = 7
if(i==7):
  if(i<15):
    print("i 15'ten küçüktür")
    if(i>1):
      print("deneme")
  elif(i<8):
    print("i 8 den küçüktür")
  else:
    print("i 7den küçüktür")

a = 20

if(a==8):
  print("a 8dir")
elif(a==15):
  print("a 15tir")
elif(a==20):
  print("a 20dir")
else:
  print("kosullar saglanmadı")

if a < 21: print("a küçüktür 21") #short hand yazım şekli


#2 ye bölme kontrolü

sayi = 8

if sayi % 2 == 0:
  print("çift sayıdır")
else:
  print("tek sayıdır")

#and ve or operatorleri
print("##########")

a=3
b=2
c=1

if a<b or b>c: #or ifadelerde kosullardan 1nin dogru olması yeterli
  print("or kosulu")
else:
  print("kosullar saglanmadı")

if a<b and b>c: #and ifadelerde kosullardan hepsinin dogru olması lazım
  print("or kosulu")
else:
  print("kosullar saglanmadı")

x = 200
y = 1000

if ((y<x) or (y%2 == 0)):
  print("xyz")

print("######")


list = [1,2,3,4]
a = 5

if a in list:
  print(" a harfi liste elemanıdır")
else:
  print("a harfi liste elemanı değildir")

kelime = "Hale"
harf = "H"

if harf in kelime:
  print("H harfi kelimenin bir harfidir")
else:
  print("H harfi kelimede bulunmuyor")

sayi = int(input())

if sayi < 20:
  print("Sayi 20 den küçüktür")
elif sayi == 20:
  print("sayi 20 ye eşittir")
else:
  print("20 den büyüktür")

# %%
#For ve while döngüsü

for i in range(0,5): #(baslangic degeri, bitis degeri) baslangıc degeri dahil bitis degeri dahil degil
  print(i)

print("######")

for i in range(0,20,4): #bitisin sagına yazılan deger kacar kacar olacagını söyler
  print(i)

#2 üzeri 5'i bulalım

sonuc = 1
for i in range(0,5):
  sonuc*=2
print("2 üzeri 5", sonuc)

print("########")

for i in range(1,3):
  for j in range(1,3):
    print(i,j)

list = [1,2,3,4,5]

for rakam in list:
  print(rakam)

isim = "hale"

for harf in isim:
  print(harf)

demet = (0,9,8,7)

for rakam in demet:
  print(rakam)

print("///////////////")
#döngülerde koşullar



liste = [1,2,3,4,5,6]

for i in liste:
  if i ==1:
    continue
  print(i)


for i in liste:
  if i == 3:
    break;
  print(i)

print("////////////")
liste = range(10)

for i in liste:
  if i%3 !=0:
    continue
  print(i)

# %%
#While döngüsü

#while True: #sonsuz döngü için true ile baslanır
#  print("Selam")

a = 0
while(a<3):
  a = a +1
  print("Selam")

#kosul vererek sonsuz döngü oluşturma
yas = 23

#while(yas>18):
#  print("Sonsuz döngü")

i = 1
while (i<8):
  print(i)
  if i == 4:
    break
  i+=1

y=1
while y<6:
  print(y)
  y +=1
else:
  print("yazı")

a=1
while True:
  if a % 2 == 0:
    a +=1
    continue
  print(a)

  a+=1

  if a == 8:
    break

# %%
#Klavyeden girilen sayıya kadar olan sayıların toplamı

okul = int(input("Sayı girin:"))
toplam = 0

for i in range(1,okul+1):
  toplam += i
print("Sayıların toplamı:", toplam)


#5 4 3 2 1
#4 3 2 1
#3 2 1
#2 1
#1

a=5
b=5

for i in range(0,a+1):
  for j in range(b-i, 0 ,-1):
    print(j, end='')
  print()


#Başlangıç ve bitiş değerleri arasındaki asal sayıları bulmak

baslangic = 7
bitis = 50

for numara in range(baslangic, bitis+1):
  if numara >1:
    for i in range(2,numara):
      if(numara%i) == 0:
        break
    else:
      print(numara)
